# %% [markdown]
# <a href="https://colab.research.google.com/github/Charan-AB/Credit_card_detection/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import sklearn

# %% [markdown]
# Data Importing

# %%
data = pd.read_csv('creditcard.csv')

# %% [markdown]
# Exploring dataset

# %%
print(data.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
print(data.shape)
data = data.sample(frac = 0.2, random_state = 1)
print(data.shape)
# Out:
# (12263, 31)
# (2453, 31)

# %% [markdown]
# Histogram plot for parameters

# %%
data.hist(figsize = (20, 20))
plt.show()

# %% [markdown]
# Calculating number of fraud cases

# %%
fraud = data[data['Class'] == 1]
valid = data[data['Class'] == 0]

outlier_fraction = len(fraud) / float(len(valid))
print(outlier_fraction)

print('Fraud Cases: {}'.format(len(fraud)))
print('Valid Cases: {}'.format(len(valid)))
# Out:
# 0.005740057400574006
# Fraud Cases: 14
# Valid Cases: 2439

# %% [markdown]
# Correlation matrix

# %%
corrmat = data.corr()
fig = plt.figure(figsize = (12, 9))

sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()

# %% [markdown]
# Organizing the data

# %%
columns = data.columns.tolist()

columns = [c for c in columns if c not in ['Class']]

target = 'Class'

X = data[columns]
Y = data[target]

print(X.shape)
print(Y.shape)
# Out:
# (2453, 30)
# (2453,)

# %% [markdown]
# Applying ALGORITHMS

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

# %%
state = 1

classifiers = {
    'Isolation Forest': IsolationForest(max_samples = len(X),
                                       contamination = outlier_fraction,
                                       random_state = state),
 
    'Local Outlier Factor': LocalOutlierFactor(
    n_neighbors = 20,
    contamination = outlier_fraction)
}

# %% [markdown]
# Fit the model

# %%
n_outliers = len(fraud)

for i, (clf_name, clf) in enumerate(classifiers.items()):
    
    if clf_name == 'Local Outlier Factor':
        y_pred = clf.fit_predict(X)
        scores_pred = clf.negative_outlier_factor_
    else:
        clf.fit(X)
        scores_pred = clf.decision_function(X)
        y_pred = clf.predict(X)

    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1

    n_errors = (y_pred != Y).sum()
    
    print('{}: {}'.format(clf_name, n_errors))
    print(accuracy_score(Y, y_pred))
    print(classification_report(Y, y_pred))
# Out:
# Isolation Forest: 13
# 0.9947003668976763
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2439
#          1.0       0.53      0.57      0.55        14
#
#     accuracy                           0.99      2453
#    macro avg       0.77      0.78      0.77      2453
# weighted avg       0.99      0.99      0.99      2453
#
# Local Outlier Factor: 29
# 0.9881777415409703
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      2439
#          1.0       0.00      0.00      0.00        14
#
#     accuracy                           0.99      2453
#    macro avg       0.50      0.50      0.50      2453
# weighted avg       0.99      0.99      0.99      2453
